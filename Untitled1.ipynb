# %% [markdown]
# <a href="https://colab.research.google.com/github/dongin0524/python/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

fail,big,small,count=0,0,0,0

while True:
    count = count + 1

    a = random.randrange(1,7)
    b = random.randrange(1,7)
    c = random.randrange(1,7)

    if a+b+c == 3 or a+b+c==18:
      fail = fail + 1
    elif a+b+c<11 :
      small = small+1
    else:
      big = big + 1
    print('big확률:{0}, small확률: {1}'.format((big/count)*100,(small/count)*100))
    time.sleep(0.1)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# big확률:49.41655359565807, small확률: 49.71506105834464
# big확률:49.419985075639374, small확률: 49.71168848789092
# big확률:49.416632749966084, small확률: 49.71509971509971
# big확률:49.41328087906125, small확률: 49.718510479549614
# big확률:49.40992946283234, small확률: 49.72192078133478
# big확률:49.413360461173276, small확률: 49.7185486605629
# big확률:49.410009494100095, small확률: 49.72195849721959
# big확률:49.40665898148776, small확률: 49.72536787143147
# big확률:49.40330892324383, small확률: 49.72877678329265
# big확률:49.39995931927588, small확률: 49.732185232897145
# big확률:49.396610169491524, small확률: 49.735593220338984
# big확률:49.39326147379839, small확률: 49.739000745712154
# big확률:49.39669197396963, small확률: 49.73562906724512
# big확률:49.4001220090829, small확률: 49.73225784586186
# big확률:49.39677375626948, small확률: 49.735664904432696
# big확률:49.39342595730261, small확률: 49.73907150118604
# big확률:49.39685551640011, small확률: 49.735700731905666
# ...
